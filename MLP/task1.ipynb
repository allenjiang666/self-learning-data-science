# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Loada-the-data" data-toc-modified-id="Loada-the-data-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Loada the data</a></span></li><li><span><a href="#Define-X-and-y" data-toc-modified-id="Define-X-and-y-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Define X and y</a></span></li><li><span><a href="#Visualize-the-data" data-toc-modified-id="Visualize-the-data-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Visualize the data</a></span></li><li><span><a href="#Split-data" data-toc-modified-id="Split-data-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Split data</a></span></li><li><span><a href="#Set-up-mlp-model" data-toc-modified-id="Set-up-mlp-model-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Set up mlp model</a></span></li><li><span><a href="#Complie-the-mlp-model" data-toc-modified-id="Complie-the-mlp-model-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Complie the mlp model</a></span></li><li><span><a href="#Train-the-model" data-toc-modified-id="Train-the-model-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Train the model</a></span></li><li><span><a href="#Make-prediction-and-calculate-accuracy" data-toc-modified-id="Make-prediction-and-calculate-accuracy-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Make prediction and calculate accuracy</a></span></li><li><span><a href="#Generate-new-data-for-plot" data-toc-modified-id="Generate-new-data-for-plot-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Generate new data for plot</a></span></li><li><span><a href="#Format-the-output" data-toc-modified-id="Format-the-output-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Format the output</a></span></li></ul></div>

# %% [markdown]
# # Keras

# %% [raw]
# 基于data.csv数据，建立mlp模型，计算其在测试数据上的准确率，可视化模型预测结果：
#
# 1.进行数据分离：test_size=0.33,random_state=10
# 2.模型结构：一层隐藏层，有20个神经元

# %% [markdown]
# ## Loada the data

# %%
import pandas as pd
import numpy as np
data = pd.read_csv('data.csv')
data.head()
# Out:
#        x1      x2  y
# 0  0.0323  0.0244  1
# 1  0.0887  0.0244  1
# 2  0.1690  0.0163  1
# 3  0.2420  0.0000  1
# 4  0.2420  0.0488  1

# %% [markdown]
# ## Define X and y

# %%
X = data[['x1','x2']]
y = data.y
X.head()
# Out:
#        x1      x2
# 0  0.0323  0.0244
# 1  0.0887  0.0244
# 2  0.1690  0.0163
# 3  0.2420  0.0000
# 4  0.2420  0.0488

# %% [markdown]
# ## Visualize the data

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
fig1 = plt.figure(figsize=(5,5))
good = plt.scatter(X.x1[y==1] ,X.x2[y==1])
bad = plt.scatter(X.x1[y==0], X.x2[y==0])
plt.title('Raw Data')
plt.xlabel('x1')
plt.ylabel('x2')
plt.legend((good,bad),('Good sample','Bad sample'))
plt.show()

# %% [markdown]
# ## Split data

# %%
from sklearn.model_selection import train_test_split
X_train, X_test,y_train, y_test = train_test_split(X, y, test_size =.33, random_state=10)
X_train.shape, X_test.shape, X.shape
# Out:
# ((275, 2), (136, 2), (411, 2))

# %% [markdown]
# ## Set up mlp model

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation
mlp = Sequential()
mlp.add(Dense(units=20, input_dim=2, activation='sigmoid'))
mlp.add(Dense(units=1,activation='sigmoid'))
mlp.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_3 (Dense)              (None, 20)                60
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 21
# ...
# Total params: 81
# Trainable params: 81
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Complie the mlp model

# %%
mlp.compile(optimizer='adam', loss='binary_crossentropy')

# %% [markdown]
# ## Train the model

# %%
mlp.fit(X_train, y_train, epochs=4000)
# Out:
# Epoch 1/4000
# 275/275 [==============================] - 0s 93us/step - loss: 0.2954
# Epoch 2/4000
# 275/275 [==============================] - 0s 84us/step - loss: 0.2952
# Epoch 3/4000
# 275/275 [==============================] - 0s 95us/step - loss: 0.2951
# Epoch 4/4000
# 275/275 [==============================] - 0s 100us/step - loss: 0.2951
# Epoch 5/4000
# 275/275 [==============================] - 0s 107us/step - loss: 0.2952
# Epoch 6/4000
# 275/275 [==============================] - 0s 89us/step - loss: 0.2950
# Epoch 7/4000
# 275/275 [==============================] - 0s 90us/step - loss: 0.2949
# Epoch 8/4000
# 275/275 [==============================] - 0s 89us/step - loss: 0.2949
# Epoch 9/4000
# 275/275 [==============================] - 0s 68us/step - loss: 0.2951
# Epoch 10/4000
# 275/275 [==============================] - 0s 62us/step - loss: 0.2951
# Epoch 11/4000
# 275/275 [==============================] - 0s 62us/step - loss: 0.2947
# Epoch 12/4000
# ...

# %% [markdown]
# ## Make prediction and calculate accuracy

# %%
from sklearn.metrics import accuracy_score
y_train_predicted = mlp.predict_classes(X_train)
accuracy_train = accuracy_score(y_train, y_train_predicted)
print('Accuracy score on train data set is ', accuracy_train)
# Out:
# Accuracy score on train data set is  0.9927272727272727

# %%
#make prediction based on the test data
y_test_predicted = mlp.predict_classes(X_test)
accuracy_test = accuracy_score(y_test, y_test_predicted)
print('Accuracy score on train data set is ', accuracy_test)
# Out:
# Accuracy score on train data set is  0.9852941176470589

# %%
y_test_predicted.shape
# Out:
# (136, 1)

# %% [markdown]
# ## Generate new data for plot

# %%
xx, yy = np.meshgrid(np.arange(0,1,0.01),np.arange(0,1,0.01))
x_range = np.c_[xx.ravel(),yy.ravel()]
y_range_predict = mlp.predict_classes(x_range)
print(type(y_range_predict))
# Out:
# <class 'numpy.ndarray'>

# %%
pd.DataFrame(x_range).head(10)
# Out:
#       0    1
# 0  0.00  0.0
# 1  0.01  0.0
# 2  0.02  0.0
# 3  0.03  0.0
# 4  0.04  0.0
# 5  0.05  0.0
# 6  0.06  0.0
# 7  0.07  0.0
# 8  0.08  0.0
# 9  0.09  0.0

# %%
y_range_predict.shape
# Out:
# (10000, 1)

# %% [markdown]
# ## Format the output

# %%
y_range_predict_form = pd.Series(i[0] for i in y_range_predict)

y_range_predict_form.shape
# Out:
# (10000,)

# %%
fig2 = plt.figure(figsize=(5,5))
passed_predict=plt.scatter(x_range[:,0][y_range_predict_form==1],x_range[:,1][y_range_predict_form==1])
failed_predict=plt.scatter(x_range[:,0][y_range_predict_form==0],x_range[:,1][y_range_predict_form==0])

passed=plt.scatter(X.loc[:,'x1'][y==1],X.loc[:,'x2'][y==1])
failed=plt.scatter(X.loc[:,'x1'][y==0],X.loc[:,'x2'][y==0])
plt.legend((passed,failed,passed_predict,failed_predict),('passed','failed','passed_predict','failed_predict'))
plt.xlabel('x1')
plt.ylabel('x2')
plt.title('prediction result')
plt.show()

# %% [raw]
# 好坏质检二分类mlp实战summary：
# 1、通过mlp模型，在不增加特征项的情况下，实现了非线性二分类任务；
# 2、掌握了mlp模型的建立、配置与训练方法，并实现基于新数据的预测；
# 3、熟悉了mlp分类的预测数据格式，并实现格式转换；
# 4、核心算法参考链接：https://keras-cn.readthedocs.io/en/latest/#30skeras
