# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('input000.txt', sep='\t',skiprows=[0],header=None, names=['date','level'])
#data.columns = ["a", "b", "c", "etc."]

# %%
df.head()
# Out:
#                 date   level
# 0  1/3/2012 16:00:00   26.96
# 1  1/4/2012 16:00:00   27.47
# 2  1/5/2012 16:00:00  27.728
# 3  1/6/2012 16:00:00   28.19
# 4  1/9/2012 16:00:00    28.1

# %%
data.shape
# Out:
# (250, 2)

# %%
from datetime import datetime

# %%
# Reassign the sale_date column to be a datetime type
df['date'] = pd.to_datetime(df['date'])

# Sort rows by the date and then set the index as that date
df = df.sort_values("date").set_index("date")

# %%
df['level'][df['level'].str.contains('Missing')]=np.nan

# %%
df['level'].astype('float')
# Out:
# date
# 2012-01-03 16:00:00    26.960
# 2012-01-04 16:00:00    27.470
# 2012-01-05 16:00:00    27.728
# 2012-01-06 16:00:00    28.190
# 2012-01-09 16:00:00    28.100
#                         ...
# 2012-12-24 13:00:00    27.250
# 2012-12-26 16:00:00    27.200
# 2012-12-27 16:00:00    27.090
# 2012-12-28 16:00:00    26.900
# 2012-12-31 16:00:00    26.770
# Name: level, Length: 250, dtype: float64

# %%
from matplotlib import pyplot as plt

# %%
plt.plot(df.index[~df['level'].isna()],df.level[~df['level'].isna()])

# %%
df['level'].isna()
# Out:
# date
# 2012-01-03 16:00:00    False
# 2012-01-04 16:00:00    False
# 2012-01-05 16:00:00    False
# 2012-01-06 16:00:00    False
# 2012-01-09 16:00:00    False
#                        ...
# 2012-12-24 13:00:00    False
# 2012-12-26 16:00:00    False
# 2012-12-27 16:00:00    False
# 2012-12-28 16:00:00    False
# 2012-12-31 16:00:00    False
# Name: level, Length: 250, dtype: bool
